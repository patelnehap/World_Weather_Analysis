# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = list(zip(lats, lngs))

# %%
# Add the latitudes and longitudes to a list
coordinates = lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
       cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 717

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=51ffd159d5ab0c3f8f40f32edccc615a

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mantua
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | barcelos
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | oksovskiy
# Processing Record 13 of Set 1 | okhotsk
# Processing Record 14 of Set 1 | darnah
# Processing Record 15 of Set 1 | balkhash
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | adrar
# Processing Record 19 of Set 1 | banda aceh
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 1 | chumikan
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | zhezkazgan
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | shimoda
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | tautira
# Processing Record 35 of Set 1 | columbus
# Processing Record 36 of Set 1 | diamantino
# Processing Record 37 of Set 1 | agadez
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | chowchilla
# Processing Record 40 of Set 1 | ucluelet
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | venado tuerto
# Processing Record 43 of Set 1 | abnub
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | golden
# Processing Record 46 of Set 1 | formosa
# Processing Record 47 of Set 1 | raton
# Processing Record 48 of Set 1 | necochea
# Processing Record 49 of Set 1 | acuna
# City not found. Skipping...
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | miraflores
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | biak
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | caravelas
# Processing Record 11 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 12 of Set 2 | muros
# Processing Record 13 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 2 | huilong
# Processing Record 15 of Set 2 | coahuayana
# Processing Record 16 of Set 2 | enkoping
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | den helder
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | antalaha
# Processing Record 22 of Set 2 | christchurch
# Processing Record 23 of Set 2 | tres marias
# Processing Record 24 of Set 2 | sur
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | mandurah
# Processing Record 27 of Set 2 | raudeberg
# Processing Record 28 of Set 2 | glens falls
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | amapa
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 2 | buala
# Processing Record 36 of Set 2 | goderich
# Processing Record 37 of Set 2 | sakaiminato
# Processing Record 38 of Set 2 | calabazar de sagua
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | riverton
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | busselton
# Processing Record 46 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | kislovodsk
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | lisakovsk
# Processing Record 2 of Set 3 | nome
# Processing Record 3 of Set 3 | padang
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | sault sainte marie
# Processing Record 6 of Set 3 | emerald
# Processing Record 7 of Set 3 | narsaq
# Processing Record 8 of Set 3 | vila franca do campo
# Processing Record 9 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 10 of Set 3 | lourdes
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | torbay
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | lasa
# Processing Record 15 of Set 3 | beloha
# Processing Record 16 of Set 3 | stony plain
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | dwarka
# Processing Record 20 of Set 3 | kharp
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | nantucket
# Processing Record 25 of Set 3 | luau
# Processing Record 26 of Set 3 | hokitika
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | cayenne
# Processing Record 29 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | kununurra
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 3 | lompoc
# Processing Record 36 of Set 3 | cabinda
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | bernalillo
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | manzanillo
# Processing Record 43 of Set 3 | cusuna
# Processing Record 44 of Set 3 | hilo
# Processing Record 45 of Set 3 | ust-maya
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | makakilo city
# Processing Record 48 of Set 3 | codrington
# Processing Record 49 of Set 3 | ahipara
# Processing Record 50 of Set 3 | whitehorse
# Processing Record 1 of Set 4 | gidole
# Processing Record 2 of Set 4 | yellowknife
# Processing Record 3 of Set 4 | aba
# Processing Record 4 of Set 4 | bathsheba
# Processing Record 5 of Set 4 | bubaque
# Processing Record 6 of Set 4 | caiaponia
# Processing Record 7 of Set 4 | sao jose da coroa grande
# Processing Record 8 of Set 4 | norman wells
# Processing Record 9 of Set 4 | tigil
# Processing Record 10 of Set 4 | comodoro rivadavia
# Processing Record 11 of Set 4 | moussoro
# Processing Record 12 of Set 4 | port said
# Processing Record 13 of Set 4 | viedma
# Processing Record 14 of Set 4 | tazmalt
# Processing Record 15 of Set 4 | harper
# Processing Record 16 of Set 4 | college
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | sinnamary
# Processing Record 20 of Set 4 | ullapool
# Processing Record 21 of Set 4 | novo aripuana
# Processing Record 22 of Set 4 | ushumun
# Processing Record 23 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | boa vista
# Processing Record 26 of Set 4 | tahoua
# Processing Record 27 of Set 4 | ust-charyshskaya pristan
# Processing Record 28 of Set 4 | manitouwadge
# Processing Record 29 of Set 4 | ancud
# Processing Record 30 of Set 4 | madimba
# Processing Record 31 of Set 4 | sorong
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | pajapan
# Processing Record 34 of Set 4 | macusani
# Processing Record 35 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 37 of Set 4 | eidsvag
# Processing Record 38 of Set 4 | faya
# Processing Record 39 of Set 4 | vaini
# Processing Record 40 of Set 4 | hambantota
# Processing Record 41 of Set 4 | tuktoyaktuk
# Processing Record 42 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | khandyga
# Processing Record 45 of Set 4 | westport
# Processing Record 46 of Set 4 | huejuquilla el alto
# Processing Record 47 of Set 4 | chaozhou
# Processing Record 48 of Set 4 | la ronge
# Processing Record 49 of Set 4 | manavalakurichi
# Processing Record 50 of Set 4 | berezanka
# Processing Record 1 of Set 5 | etchoropo
# Processing Record 2 of Set 5 | palmer
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | kamskiye polyany
# Processing Record 5 of Set 5 | sampit
# Processing Record 6 of Set 5 | shitanjing
# Processing Record 7 of Set 5 | alice springs
# Processing Record 8 of Set 5 | tadine
# Processing Record 9 of Set 5 | khatanga
# Processing Record 10 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 5 | haverfordwest
# Processing Record 12 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 5 | ornskoldsvik
# Processing Record 14 of Set 5 | coihaique
# Processing Record 15 of Set 5 | kolokani
# Processing Record 16 of Set 5 | praia da vitoria
# Processing Record 17 of Set 5 | oriximina
# Processing Record 18 of Set 5 | payson
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 22 of Set 5 | bethel
# Processing Record 23 of Set 5 | jizan
# Processing Record 24 of Set 5 | tanout
# Processing Record 25 of Set 5 | borogontsy
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 28 of Set 5 | xining
# Processing Record 29 of Set 5 | bratsk
# Processing Record 30 of Set 5 | livramento
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | ormara
# Processing Record 33 of Set 5 | soyo
# Processing Record 34 of Set 5 | constitucion
# Processing Record 35 of Set 5 | mahon
# Processing Record 36 of Set 5 | barguzin
# Processing Record 37 of Set 5 | arona
# Processing Record 38 of Set 5 | belyy yar
# Processing Record 39 of Set 5 | port blair
# Processing Record 40 of Set 5 | qandala
# Processing Record 41 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 5 | poum
# Processing Record 43 of Set 5 | acari
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | serafimovich
# Processing Record 46 of Set 5 | magistralnyy
# Processing Record 47 of Set 5 | zlynka
# Processing Record 48 of Set 5 | clyde river
# Processing Record 49 of Set 5 | nabire
# Processing Record 50 of Set 5 | klobuck
# Processing Record 1 of Set 6 | ust-nera
# Processing Record 2 of Set 6 | kemijarvi
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 6 | half moon bay
# Processing Record 6 of Set 6 | geraldton
# Processing Record 7 of Set 6 | stolin
# Processing Record 8 of Set 6 | pathein
# Processing Record 9 of Set 6 | dalaba
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | tilichiki
# Processing Record 12 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 13 of Set 6 | victor harbor
# Processing Record 14 of Set 6 | solnechnyy
# Processing Record 15 of Set 6 | guerrero negro
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | port macquarie
# Processing Record 18 of Set 6 | saint george
# Processing Record 19 of Set 6 | encheng
# Processing Record 20 of Set 6 | clearwater
# Processing Record 21 of Set 6 | nishihara
# Processing Record 22 of Set 6 | havelock
# Processing Record 23 of Set 6 | new port richey
# Processing Record 24 of Set 6 | matay
# Processing Record 25 of Set 6 | umm lajj
# Processing Record 26 of Set 6 | saskylakh
# Processing Record 27 of Set 6 | palauig
# Processing Record 28 of Set 6 | vila velha
# Processing Record 29 of Set 6 | aden
# Processing Record 30 of Set 6 | serebryansk
# Processing Record 31 of Set 6 | portland
# Processing Record 32 of Set 6 | carnarvon
# Processing Record 33 of Set 6 | lavrentiya
# Processing Record 34 of Set 6 | morant bay
# Processing Record 35 of Set 6 | cordoba
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | bairiki
# Processing Record 38 of Set 6 | phalaborwa
# Processing Record 39 of Set 6 | qinggang
# Processing Record 40 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | shishou
# Processing Record 43 of Set 6 | shenkursk
# Processing Record 44 of Set 6 | kayerkan
# Processing Record 45 of Set 6 | lakes entrance
# Processing Record 46 of Set 6 | banjar
# Processing Record 47 of Set 6 | calvinia
# Processing Record 48 of Set 6 | pariquera-acu
# City not found. Skipping...
# Processing Record 49 of Set 6 | dhidhdhoo
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | tazovskiy
# Processing Record 3 of Set 7 | san buenaventura
# Processing Record 4 of Set 7 | sept-iles
# Processing Record 5 of Set 7 | hobyo
# Processing Record 6 of Set 7 | sarai
# Processing Record 7 of Set 7 | asyut
# Processing Record 8 of Set 7 | margate
# Processing Record 9 of Set 7 | blackfoot
# Processing Record 10 of Set 7 | da nang
# Processing Record 11 of Set 7 | colares
# Processing Record 12 of Set 7 | tomatlan
# Processing Record 13 of Set 7 | ondjiva
# Processing Record 14 of Set 7 | veinticinco de mayo
# Processing Record 15 of Set 7 | santiago del estero
# Processing Record 16 of Set 7 | fare
# Processing Record 17 of Set 7 | oistins
# Processing Record 18 of Set 7 | yarmolyntsi
# Processing Record 19 of Set 7 | temir
# Processing Record 20 of Set 7 | creston
# Processing Record 21 of Set 7 | kargil
# Processing Record 22 of Set 7 | corumba
# Processing Record 23 of Set 7 | juigalpa
# Processing Record 24 of Set 7 | sitka
# Processing Record 25 of Set 7 | ergani
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | oyotun
# Processing Record 28 of Set 7 | mehamn
# Processing Record 29 of Set 7 | nador
# Processing Record 30 of Set 7 | kalasin
# Processing Record 31 of Set 7 | hervey bay
# Processing Record 32 of Set 7 | skibbereen
# Processing Record 33 of Set 7 | moss point
# Processing Record 34 of Set 7 | dingle
# Processing Record 35 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 7 | zhigansk
# Processing Record 37 of Set 7 | port hueneme
# Processing Record 38 of Set 7 | sistranda
# Processing Record 39 of Set 7 | kushmurun
# Processing Record 40 of Set 7 | hammerfest
# Processing Record 41 of Set 7 | izumo
# Processing Record 42 of Set 7 | polonnaruwa
# Processing Record 43 of Set 7 | samarai
# Processing Record 44 of Set 7 | mount pleasant
# Processing Record 45 of Set 7 | sechura
# Processing Record 46 of Set 7 | avera
# Processing Record 47 of Set 7 | nakhon sawan
# Processing Record 48 of Set 7 | haines junction
# Processing Record 49 of Set 7 | cap-aux-meules
# Processing Record 50 of Set 7 | tura
# Processing Record 1 of Set 8 | kirakira
# Processing Record 2 of Set 8 | merrill
# Processing Record 3 of Set 8 | hofn
# Processing Record 4 of Set 8 | west odessa
# Processing Record 5 of Set 8 | cao bang
# Processing Record 6 of Set 8 | olinda
# Processing Record 7 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 8 of Set 8 | richards bay
# Processing Record 9 of Set 8 | chapais
# Processing Record 10 of Set 8 | kahului
# Processing Record 11 of Set 8 | mastic beach
# Processing Record 12 of Set 8 | nago
# Processing Record 13 of Set 8 | kavieng
# Processing Record 14 of Set 8 | trofors
# Processing Record 15 of Set 8 | cockburn town
# Processing Record 16 of Set 8 | laguna
# Processing Record 17 of Set 8 | egvekinot
# Processing Record 18 of Set 8 | tarko-sale
# Processing Record 19 of Set 8 | duz
# City not found. Skipping...
# Processing Record 20 of Set 8 | troitskoye
# Processing Record 21 of Set 8 | gerash
# Processing Record 22 of Set 8 | diapaga
# Processing Record 23 of Set 8 | ingham
# Processing Record 24 of Set 8 | magalia
# Processing Record 25 of Set 8 | kang
# Processing Record 26 of Set 8 | alofi
# Processing Record 27 of Set 8 | saint-philippe
# Processing Record 28 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 8 | dunedin
# Processing Record 30 of Set 8 | mochudi
# Processing Record 31 of Set 8 | adre
# Processing Record 32 of Set 8 | cache creek
# Processing Record 33 of Set 8 | williamstown
# Processing Record 34 of Set 8 | antsohihy
# Processing Record 35 of Set 8 | cidreira
# Processing Record 36 of Set 8 | fengcheng
# Processing Record 37 of Set 8 | fairbanks
# Processing Record 38 of Set 8 | luderitz
# Processing Record 39 of Set 8 | green river
# Processing Record 40 of Set 8 | ramnagar
# Processing Record 41 of Set 8 | malatya
# Processing Record 42 of Set 8 | ambilobe
# Processing Record 43 of Set 8 | kanniyakumari
# Processing Record 44 of Set 8 | boquira
# Processing Record 45 of Set 8 | tanuku
# Processing Record 46 of Set 8 | dir
# Processing Record 47 of Set 8 | rawson
# Processing Record 48 of Set 8 | omsukchan
# Processing Record 49 of Set 8 | nioro
# Processing Record 50 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 1 of Set 9 | iberia
# Processing Record 2 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 9 | praya
# Processing Record 4 of Set 9 | llangefni
# Processing Record 5 of Set 9 | oloron-sainte-marie
# Processing Record 6 of Set 9 | talcahuano
# Processing Record 7 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 9 | krasnoselkup
# Processing Record 9 of Set 9 | rusape
# Processing Record 10 of Set 9 | darhan
# Processing Record 11 of Set 9 | rosita
# Processing Record 12 of Set 9 | sao joao da barra
# Processing Record 13 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 9 | gat
# Processing Record 15 of Set 9 | shiraz
# Processing Record 16 of Set 9 | doka
# Processing Record 17 of Set 9 | akyab
# Processing Record 18 of Set 9 | simi
# Processing Record 19 of Set 9 | deputatskiy
# Processing Record 20 of Set 9 | rio gallegos
# Processing Record 21 of Set 9 | puerto princesa
# Processing Record 22 of Set 9 | marihatag
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | visby
# Processing Record 25 of Set 9 | angatuba
# Processing Record 26 of Set 9 | poltavka
# Processing Record 27 of Set 9 | port augusta
# Processing Record 28 of Set 9 | teluknaga
# Processing Record 29 of Set 9 | kashi
# Processing Record 30 of Set 9 | sioux lookout
# Processing Record 31 of Set 9 | asau
# Processing Record 32 of Set 9 | salinas
# Processing Record 33 of Set 9 | tukrah
# Processing Record 34 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 9 | tessalit
# Processing Record 36 of Set 9 | brufut
# Processing Record 37 of Set 9 | ballina
# Processing Record 38 of Set 9 | acarau
# Processing Record 39 of Set 9 | grindavik
# Processing Record 40 of Set 9 | jales
# Processing Record 41 of Set 9 | katsuura
# Processing Record 42 of Set 9 | papara
# Processing Record 43 of Set 9 | campbellton
# Processing Record 44 of Set 9 | najran
# Processing Record 45 of Set 9 | charters towers
# Processing Record 46 of Set 9 | havoysund
# Processing Record 47 of Set 9 | at-bashi
# Processing Record 48 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 9 | bambanglipuro
# Processing Record 50 of Set 9 | villablino
# Processing Record 1 of Set 10 | bitung
# Processing Record 2 of Set 10 | yumen
# Processing Record 3 of Set 10 | tal
# Processing Record 4 of Set 10 | polazna
# Processing Record 5 of Set 10 | victoria point
# Processing Record 6 of Set 10 | marion
# Processing Record 7 of Set 10 | moiyabana
# City not found. Skipping...
# Processing Record 8 of Set 10 | gigmoto
# Processing Record 9 of Set 10 | kumbo
# Processing Record 10 of Set 10 | taseyevo
# Processing Record 11 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 10 | yakima
# Processing Record 13 of Set 10 | aswan
# Processing Record 14 of Set 10 | imbituba
# Processing Record 15 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 10 | alexandria
# Processing Record 17 of Set 10 | ogbomosho
# Processing Record 18 of Set 10 | ostrovnoy
# Processing Record 19 of Set 10 | waipawa
# Processing Record 20 of Set 10 | salta
# Processing Record 21 of Set 10 | stromness
# Processing Record 22 of Set 10 | tabuk
# Processing Record 23 of Set 10 | baykit
# Processing Record 24 of Set 10 | doha
# Processing Record 25 of Set 10 | erenhot
# Processing Record 26 of Set 10 | san cristobal
# Processing Record 27 of Set 10 | flinders
# Processing Record 28 of Set 10 | ponor
# Processing Record 29 of Set 10 | codajas
# Processing Record 30 of Set 10 | katobu
# Processing Record 31 of Set 10 | kulachi
# Processing Record 32 of Set 10 | abu dhabi
# Processing Record 33 of Set 10 | tombouctou
# Processing Record 34 of Set 10 | luanda
# Processing Record 35 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 36 of Set 10 | lingao
# Processing Record 37 of Set 10 | rancho palos verdes
# Processing Record 38 of Set 10 | kasungu
# Processing Record 39 of Set 10 | bac lieu
# Processing Record 40 of Set 10 | dongsheng
# Processing Record 41 of Set 10 | evensk
# Processing Record 42 of Set 10 | robat karim
# Processing Record 43 of Set 10 | itupiranga
# Processing Record 44 of Set 10 | lafia
# Processing Record 45 of Set 10 | neepawa
# Processing Record 46 of Set 10 | kamenka
# Processing Record 47 of Set 10 | moses lake
# Processing Record 48 of Set 10 | general roca
# Processing Record 49 of Set 10 | shelopugino
# Processing Record 50 of Set 10 | balagansk
# Processing Record 1 of Set 11 | lorengau
# Processing Record 2 of Set 11 | corralillo
# Processing Record 3 of Set 11 | borba
# Processing Record 4 of Set 11 | sabang
# Processing Record 5 of Set 11 | trinidad
# Processing Record 6 of Set 11 | isangel
# Processing Record 7 of Set 11 | plettenberg bay
# Processing Record 8 of Set 11 | benghazi
# Processing Record 9 of Set 11 | tongzi
# Processing Record 10 of Set 11 | kendari
# Processing Record 11 of Set 11 | honningsvag
# Processing Record 12 of Set 11 | paita
# Processing Record 13 of Set 11 | nuuk
# Processing Record 14 of Set 11 | almaznyy
# Processing Record 15 of Set 11 | palermo
# Processing Record 16 of Set 11 | san jeronimo
# Processing Record 17 of Set 11 | beboto
# Processing Record 18 of Set 11 | pingzhuang
# Processing Record 19 of Set 11 | palmas bellas
# Processing Record 20 of Set 11 | ngunguru
# Processing Record 21 of Set 11 | mitsamiouli
# Processing Record 22 of Set 11 | oranjemund
# Processing Record 23 of Set 11 | camacha
# Processing Record 24 of Set 11 | santo antonio do ica
# Processing Record 25 of Set 11 | el alto
# Processing Record 26 of Set 11 | jacareacanga
# Processing Record 27 of Set 11 | madinat sittah uktubar
# Processing Record 28 of Set 11 | south sioux city
# Processing Record 29 of Set 11 | flores da cunha
# Processing Record 30 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 11 | alvinopolis
# Processing Record 32 of Set 11 | ekibastuz
# Processing Record 33 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 11 | aksu
# Processing Record 35 of Set 11 | iskateley
# Processing Record 36 of Set 11 | hamilton
# Processing Record 37 of Set 11 | hami
# Processing Record 38 of Set 11 | mindelo
# Processing Record 39 of Set 11 | aripuana
# Processing Record 40 of Set 11 | gainesville
# Processing Record 41 of Set 11 | swan river
# Processing Record 42 of Set 11 | namatanai
# Processing Record 43 of Set 11 | mana
# Processing Record 44 of Set 11 | fort stewart
# Processing Record 45 of Set 11 | rabo de peixe
# Processing Record 46 of Set 11 | husavik
# Processing Record 47 of Set 11 | komsomolskiy
# Processing Record 48 of Set 11 | mulanje
# Processing Record 49 of Set 11 | skjervoy
# Processing Record 50 of Set 11 | luba
# Processing Record 1 of Set 12 | marathon
# Processing Record 2 of Set 12 | yerbogachen
# Processing Record 3 of Set 12 | arman
# Processing Record 4 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 12 | talakan
# Processing Record 6 of Set 12 | general pico
# Processing Record 7 of Set 12 | cumbitara
# Processing Record 8 of Set 12 | catamarca
# Processing Record 9 of Set 12 | celestun
# Processing Record 10 of Set 12 | lahaina
# Processing Record 11 of Set 12 | camopi
# Processing Record 12 of Set 12 | goure
# Processing Record 13 of Set 12 | axim
# Processing Record 14 of Set 12 | mandalgovi
# Processing Record 15 of Set 12 | camapua
# Processing Record 16 of Set 12 | otuzco
# Processing Record 17 of Set 12 | taltal
# Processing Record 18 of Set 12 | buraydah
# Processing Record 19 of Set 12 | santa cruz de la palma
# Processing Record 20 of Set 12 | lotofaga
# Processing Record 21 of Set 12 | saldanha
# Processing Record 22 of Set 12 | kieta
# Processing Record 23 of Set 12 | yulara
# Processing Record 24 of Set 12 | tamasane
# Processing Record 25 of Set 12 | mahibadhoo
# Processing Record 26 of Set 12 | pital
# Processing Record 27 of Set 12 | campina verde
# Processing Record 28 of Set 12 | khorixas
# Processing Record 29 of Set 12 | elizabeth city
# Processing Record 30 of Set 12 | santa cruz
# Processing Record 31 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 12 | pasni
# Processing Record 33 of Set 12 | abha
# Processing Record 34 of Set 12 | svetlogorsk
# Processing Record 35 of Set 12 | pelym
# Processing Record 36 of Set 12 | kyren
# Processing Record 37 of Set 12 | pangnirtung
# Processing Record 38 of Set 12 | kamaishi
# Processing Record 39 of Set 12 | khani
# Processing Record 40 of Set 12 | gengenbach
# Processing Record 41 of Set 12 | revda
# Processing Record 42 of Set 12 | verkhnyaya inta
# Processing Record 43 of Set 12 | porto novo
# Processing Record 44 of Set 12 | quang ngai
# Processing Record 45 of Set 12 | canoa
# Processing Record 46 of Set 12 | beringovskiy
# Processing Record 47 of Set 12 | suhbaatar
# Processing Record 48 of Set 12 | cedar city
# Processing Record 49 of Set 12 | curry
# Processing Record 50 of Set 12 | miandrivazo
# Processing Record 1 of Set 13 | penzance
# Processing Record 2 of Set 13 | las cruces
# Processing Record 3 of Set 13 | tandil
# Processing Record 4 of Set 13 | zwedru
# Processing Record 5 of Set 13 | qaqortoq
# Processing Record 6 of Set 13 | mascota
# Processing Record 7 of Set 13 | pangody
# Processing Record 8 of Set 13 | kaeo
# Processing Record 9 of Set 13 | saint-augustin
# Processing Record 10 of Set 13 | gotsu
# Processing Record 11 of Set 13 | katangli
# Processing Record 12 of Set 13 | vila
# Processing Record 13 of Set 13 | colwyn bay
# Processing Record 14 of Set 13 | bandarbeyla
# Processing Record 15 of Set 13 | san patricio
# Processing Record 16 of Set 13 | kruisfontein
# Processing Record 17 of Set 13 | singarayakonda
# Processing Record 18 of Set 13 | miyako
# Processing Record 19 of Set 13 | grand gaube
# Processing Record 20 of Set 13 | marawi
# Processing Record 21 of Set 13 | bressuire
# Processing Record 22 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 13 | opuwo
# Processing Record 24 of Set 13 | gif-sur-yvette
# Processing Record 25 of Set 13 | seaford
# Processing Record 26 of Set 13 | mayor pablo lagerenza
# Processing Record 27 of Set 13 | russell
# Processing Record 28 of Set 13 | bandar-e lengeh
# Processing Record 29 of Set 13 | yambio
# Processing Record 30 of Set 13 | anadyr
# Processing Record 31 of Set 13 | kutum
# Processing Record 32 of Set 13 | kargasok
# Processing Record 33 of Set 13 | srednekolymsk
# Processing Record 34 of Set 13 | pascagoula
# Processing Record 35 of Set 13 | dom pedro
# Processing Record 36 of Set 13 | la maddalena
# Processing Record 37 of Set 13 | dennery
# Processing Record 38 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 13 | kharhial
# Processing Record 40 of Set 13 | chapleau
# Processing Record 41 of Set 13 | jiblah
# Processing Record 42 of Set 13 | qasigiannguit
# Processing Record 43 of Set 13 | lagos
# Processing Record 44 of Set 13 | shakhtinsk
# Processing Record 45 of Set 13 | urcos
# Processing Record 46 of Set 13 | iguai
# Processing Record 47 of Set 13 | lazaro cardenas
# Processing Record 48 of Set 13 | wembley
# Processing Record 49 of Set 13 | thinadhoo
# Processing Record 50 of Set 13 | cap malheureux
# Processing Record 1 of Set 14 | sargatskoye
# Processing Record 2 of Set 14 | baherden
# Processing Record 3 of Set 14 | carutapera
# Processing Record 4 of Set 14 | hoopstad
# Processing Record 5 of Set 14 | jardim
# Processing Record 6 of Set 14 | elban
# Processing Record 7 of Set 14 | eyemouth
# Processing Record 8 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 14 | noyabrsk
# Processing Record 10 of Set 14 | sirisia
# City not found. Skipping...
# Processing Record 11 of Set 14 | leningradskiy
# Processing Record 12 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 13 of Set 14 | pangai
# Processing Record 14 of Set 14 | mujiayingzi
# Processing Record 15 of Set 14 | belmonte
# Processing Record 16 of Set 14 | zainsk
# Processing Record 17 of Set 14 | krasnoarmeysk
# Processing Record 18 of Set 14 | carrick-on-suir
# Processing Record 19 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 20 of Set 14 | tawzar
# City not found. Skipping...
# Processing Record 21 of Set 14 | veshenskaya
# Processing Record 22 of Set 14 | sakakah
# Processing Record 23 of Set 14 | flers
# Processing Record 24 of Set 14 | gold coast
# Processing Record 25 of Set 14 | aloleng
# Processing Record 26 of Set 14 | superior
# Processing Record 27 of Set 14 | bitburg
# Processing Record 28 of Set 14 | berbera
# Processing Record 29 of Set 14 | marzuq
# Processing Record 30 of Set 14 | hirado
# Processing Record 31 of Set 14 | iquitos
# Processing Record 32 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 33 of Set 14 | solton
# Processing Record 34 of Set 14 | berlevag
# Processing Record 35 of Set 14 | tetiz
# Processing Record 36 of Set 14 | lodja
# Processing Record 37 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 38 of Set 14 | staroutkinsk
# Processing Record 39 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 40 of Set 14 | ilebo
# Processing Record 41 of Set 14 | lobito
# Processing Record 42 of Set 14 | sanchor
# Processing Record 43 of Set 14 | shebunino
# Processing Record 44 of Set 14 | vershino-darasunskiy
# Processing Record 45 of Set 14 | mitu
# Processing Record 46 of Set 14 | seoul
# Processing Record 47 of Set 14 | broome
# Processing Record 48 of Set 14 | hualmay
# Processing Record 49 of Set 14 | tulun
# Processing Record 50 of Set 14 | karratha
# Processing Record 1 of Set 15 | smolenka
# Processing Record 2 of Set 15 | benton harbor
# Processing Record 3 of Set 15 | yining
# Processing Record 4 of Set 15 | kenai
# Processing Record 5 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 6 of Set 15 | kahta
# Processing Record 7 of Set 15 | budaun
# Processing Record 8 of Set 15 | roald
# Processing Record 9 of Set 15 | tignere
# Processing Record 10 of Set 15 | fraserburgh
# Processing Record 11 of Set 15 | iwanai
# Processing Record 12 of Set 15 | machaneng
# Processing Record 13 of Set 15 | kazachinskoye
# Processing Record 14 of Set 15 | tam ky
# Processing Record 15 of Set 15 | pachino
# Processing Record 16 of Set 15 | perth
# Processing Record 17 of Set 15 | asfi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 657

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mantua      IT  45.1667   10.7833     45.64        91         100
# 1       Jamestown      US  42.0970  -79.2353     31.59        50           0
# 2        Barcelos      PT  41.5388   -8.6151     44.69        77           0
# 3           Vardo      NO  70.3705   31.1107     30.18        74         100
# 4         Ushuaia      AR -54.8000  -68.3000     46.96        62          79
# 5       Cape Town      ZA -33.9258   18.4232     61.92        59          48
# 6  Cabo San Lucas      MX  22.8909 -109.9124     72.52        57          40
# 7           Kapaa      US  22.0752 -159.3190     82.72        73          20
# 8         Rikitea      PF -23.1203 -134.9692     79.61        75           3
# 9  Ribeira Grande      PT  38.5167  -28.7000     58.77        87           2
#
#    Wind Speed Current Description
# 0        4.29       moderate rain
# 1        3.44           clear sky
# 2        5.61           clear sky
# 3       28.77     overcast clouds
# 4        5.48          light rain
# 5        7.00    scattered clouds
# 6       11.50    scattered clouds
# 7        6.91          light rain
# 8       16.82           clear sky
# 9        8.99           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# Its in the same order but the code to reorder:
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mantua      IT  45.1667   10.7833     45.64        91         100
# 1       Jamestown      US  42.0970  -79.2353     31.59        50           0
# 2        Barcelos      PT  41.5388   -8.6151     44.69        77           0
# 3           Vardo      NO  70.3705   31.1107     30.18        74         100
# 4         Ushuaia      AR -54.8000  -68.3000     46.96        62          79
# 5       Cape Town      ZA -33.9258   18.4232     61.92        59          48
# 6  Cabo San Lucas      MX  22.8909 -109.9124     72.52        57          40
# 7           Kapaa      US  22.0752 -159.3190     82.72        73          20
# 8         Rikitea      PF -23.1203 -134.9692     79.61        75           3
# 9  Ribeira Grande      PT  38.5167  -28.7000     58.77        87           2
#
#    Wind Speed Current Description
# 0        4.29       moderate rain
# 1        3.44           clear sky
# 2        5.61           clear sky
# 3       28.77     overcast clouds
# 4        5.48          light rain
# 5        7.00    scattered clouds
# 6       11.50    scattered clouds
# 7        6.91          light rain
# 8       16.82           clear sky
# 9        8.99           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
